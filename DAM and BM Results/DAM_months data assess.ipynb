# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import datetime as dt
from datetime import datetime
from pandas import concat
from math import sqrt
from sklearn import preprocessing
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error as MAPE

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import accuracy_score, make_scorer
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.utils import check_array
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from epftoolbox.evaluation import sMAPE
# from epftoolbox.evaluation import MAPE 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
date_format="%m/%d/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat1 = pd.read_csv("/home/ciaran/Documents/DAM_1-3.csv")
dat2 = pd.read_csv("/home/ciaran/Documents/DAM_4-6.csv")
dat3 = pd.read_csv("/home/ciaran/Documents/DAM_7-9.csv")
dat4 = pd.read_csv("/home/ciaran/Documents/DAM_10-12.csv")

dat1=pd.DataFrame(dat1)
dat2=pd.DataFrame(dat2)
dat3=pd.DataFrame(dat3)
dat4=pd.DataFrame(dat4)

# %%
lag_0y1_Forecast=dat1['EURPrices_Forecast']
lag_0y1_Forecast=lag_0y1_Forecast.dropna()
lag_1y1_Forecast=dat1['EURPrices+1_Forecast']
lag_1y1_Forecast=lag_1y1_Forecast.dropna()
lag_2y1_Forecast=dat1['EURPrices+2_Forecast']
lag_2y1_Forecast=lag_2y1_Forecast.dropna()
lag_3y1_Forecast=dat1['EURPrices+3_Forecast']
lag_3y1_Forecast=lag_3y1_Forecast.dropna()
lag_4y1_Forecast=dat1['EURPrices+4_Forecast']
lag_4y1_Forecast=lag_4y1_Forecast.dropna()
lag_5y1_Forecast=dat1['EURPrices+5_Forecast']
lag_5y1_Forecast=lag_5y1_Forecast.dropna()
lag_6y1_Forecast=dat1['EURPrices+6_Forecast']
lag_6y1_Forecast=lag_6y1_Forecast.dropna()
lag_7y1_Forecast=dat1['EURPrices+7_Forecast']
lag_7y1_Forecast=lag_7y1_Forecast.dropna()
lag_8y1_Forecast=dat1['EURPrices+8_Forecast']
lag_8y1_Forecast=lag_8y1_Forecast.dropna()
lag_9y1_Forecast=dat1['EURPrices+9_Forecast']
lag_9y1_Forecast=lag_9y1_Forecast.dropna()
lag_10y1_Forecast=dat1['EURPrices+10_Forecast']
lag_10y1_Forecast=lag_10y1_Forecast.dropna()
lag_11y1_Forecast=dat1['EURPrices+11_Forecast']
lag_11y1_Forecast=lag_11y1_Forecast.dropna()
lag_12y1_Forecast=dat1['EURPrices+12_Forecast']
lag_12y1_Forecast=lag_12y1_Forecast.dropna()
lag_13y1_Forecast=dat1['EURPrices+13_Forecast']
lag_13y1_Forecast=lag_13y1_Forecast.dropna()
lag_14y1_Forecast=dat1['EURPrices+14_Forecast']
lag_14y1_Forecast=lag_14y1_Forecast.dropna()
lag_15y1_Forecast=dat1['EURPrices+15_Forecast']
lag_15y1_Forecast=lag_15y1_Forecast.dropna()
lag_16y1_Forecast=dat1['EURPrices+16_Forecast']
lag_16y1_Forecast=lag_16y1_Forecast.dropna()
lag_17y1_Forecast=dat1['EURPrices+17_Forecast']
lag_17y1_Forecast=lag_17y1_Forecast.dropna()
lag_18y1_Forecast=dat1['EURPrices+18_Forecast']
lag_18y1_Forecast=lag_18y1_Forecast.dropna()
lag_19y1_Forecast=dat1['EURPrices+19_Forecast']
lag_19y1_Forecast=lag_19y1_Forecast.dropna()
lag_20y1_Forecast=dat1['EURPrices+20_Forecast']
lag_20y1_Forecast=lag_20y1_Forecast.dropna()
lag_21y1_Forecast=dat1['EURPrices+21_Forecast']
lag_21y1_Forecast=lag_21y1_Forecast.dropna()
lag_22y1_Forecast=dat1['EURPrices+22_Forecast']
lag_22y1_Forecast=lag_22y1_Forecast.dropna()
lag_23y1_Forecast=dat1['EURPrices+23_Forecast']
lag_23y1_Forecast=lag_23y1_Forecast.dropna()
pred_nn1=pd.concat([lag_0y1_Forecast, lag_1y1_Forecast, lag_2y1_Forecast, lag_3y1_Forecast, lag_4y1_Forecast, 
                    lag_5y1_Forecast, lag_6y1_Forecast, lag_7y1_Forecast, lag_8y1_Forecast, lag_9y1_Forecast,
                    lag_10y1_Forecast, lag_11y1_Forecast, lag_12y1_Forecast, lag_13y1_Forecast, lag_14y1_Forecast,
                    lag_15y1_Forecast, lag_16y1_Forecast, lag_17y1_Forecast, lag_18y1_Forecast, lag_19y1_Forecast,
                    lag_20y1_Forecast, lag_21y1_Forecast, lag_22y1_Forecast, lag_23y1_Forecast], axis=1)


lag_0y1_Forecast=dat2['EURPrices_Forecast']
lag_0y1_Forecast=lag_0y1_Forecast.dropna()
lag_1y1_Forecast=dat2['EURPrices+1_Forecast']
lag_1y1_Forecast=lag_1y1_Forecast.dropna()
lag_2y1_Forecast=dat2['EURPrices+2_Forecast']
lag_2y1_Forecast=lag_2y1_Forecast.dropna()
lag_3y1_Forecast=dat2['EURPrices+3_Forecast']
lag_3y1_Forecast=lag_3y1_Forecast.dropna()
lag_4y1_Forecast=dat2['EURPrices+4_Forecast']
lag_4y1_Forecast=lag_4y1_Forecast.dropna()
lag_5y1_Forecast=dat2['EURPrices+5_Forecast']
lag_5y1_Forecast=lag_5y1_Forecast.dropna()
lag_6y1_Forecast=dat2['EURPrices+6_Forecast']
lag_6y1_Forecast=lag_6y1_Forecast.dropna()
lag_7y1_Forecast=dat2['EURPrices+7_Forecast']
lag_7y1_Forecast=lag_7y1_Forecast.dropna()
lag_8y1_Forecast=dat2['EURPrices+8_Forecast']
lag_8y1_Forecast=lag_8y1_Forecast.dropna()
lag_9y1_Forecast=dat2['EURPrices+9_Forecast']
lag_9y1_Forecast=lag_9y1_Forecast.dropna()
lag_10y1_Forecast=dat2['EURPrices+10_Forecast']
lag_10y1_Forecast=lag_10y1_Forecast.dropna()
lag_11y1_Forecast=dat2['EURPrices+11_Forecast']
lag_11y1_Forecast=lag_11y1_Forecast.dropna()
lag_12y1_Forecast=dat2['EURPrices+12_Forecast']
lag_12y1_Forecast=lag_12y1_Forecast.dropna()
lag_13y1_Forecast=dat2['EURPrices+13_Forecast']
lag_13y1_Forecast=lag_13y1_Forecast.dropna()
lag_14y1_Forecast=dat2['EURPrices+14_Forecast']
lag_14y1_Forecast=lag_14y1_Forecast.dropna()
lag_15y1_Forecast=dat2['EURPrices+15_Forecast']
lag_15y1_Forecast=lag_15y1_Forecast.dropna()
lag_16y1_Forecast=dat2['EURPrices+16_Forecast']
lag_16y1_Forecast=lag_16y1_Forecast.dropna()
lag_17y1_Forecast=dat2['EURPrices+17_Forecast']
lag_17y1_Forecast=lag_17y1_Forecast.dropna()
lag_18y1_Forecast=dat2['EURPrices+18_Forecast']
lag_18y1_Forecast=lag_18y1_Forecast.dropna()
lag_19y1_Forecast=dat2['EURPrices+19_Forecast']
lag_19y1_Forecast=lag_19y1_Forecast.dropna()
lag_20y1_Forecast=dat2['EURPrices+20_Forecast']
lag_20y1_Forecast=lag_20y1_Forecast.dropna()
lag_21y1_Forecast=dat2['EURPrices+21_Forecast']
lag_21y1_Forecast=lag_21y1_Forecast.dropna()
lag_22y1_Forecast=dat2['EURPrices+22_Forecast']
lag_22y1_Forecast=lag_22y1_Forecast.dropna()
lag_23y1_Forecast=dat2['EURPrices+23_Forecast']
lag_23y1_Forecast=lag_23y1_Forecast.dropna()
pred_nn2=pd.concat([lag_0y1_Forecast, lag_1y1_Forecast, lag_2y1_Forecast, lag_3y1_Forecast, lag_4y1_Forecast, 
                    lag_5y1_Forecast, lag_6y1_Forecast, lag_7y1_Forecast, lag_8y1_Forecast, lag_9y1_Forecast,
                    lag_10y1_Forecast, lag_11y1_Forecast, lag_12y1_Forecast, lag_13y1_Forecast, lag_14y1_Forecast,
                    lag_15y1_Forecast, lag_16y1_Forecast, lag_17y1_Forecast, lag_18y1_Forecast, lag_19y1_Forecast,
                    lag_20y1_Forecast, lag_21y1_Forecast, lag_22y1_Forecast, lag_23y1_Forecast], axis=1)

lag_0y1_Forecast=dat3['EURPrices_Forecast']
lag_0y1_Forecast=lag_0y1_Forecast.dropna()
lag_1y1_Forecast=dat3['EURPrices+1_Forecast']
lag_1y1_Forecast=lag_1y1_Forecast.dropna()
lag_2y1_Forecast=dat3['EURPrices+2_Forecast']
lag_2y1_Forecast=lag_2y1_Forecast.dropna()
lag_3y1_Forecast=dat3['EURPrices+3_Forecast']
lag_3y1_Forecast=lag_3y1_Forecast.dropna()
lag_4y1_Forecast=dat3['EURPrices+4_Forecast']
lag_4y1_Forecast=lag_4y1_Forecast.dropna()
lag_5y1_Forecast=dat3['EURPrices+5_Forecast']
lag_5y1_Forecast=lag_5y1_Forecast.dropna()
lag_6y1_Forecast=dat3['EURPrices+6_Forecast']
lag_6y1_Forecast=lag_6y1_Forecast.dropna()
lag_7y1_Forecast=dat3['EURPrices+7_Forecast']
lag_7y1_Forecast=lag_7y1_Forecast.dropna()
lag_8y1_Forecast=dat3['EURPrices+8_Forecast']
lag_8y1_Forecast=lag_8y1_Forecast.dropna()
lag_9y1_Forecast=dat3['EURPrices+9_Forecast']
lag_9y1_Forecast=lag_9y1_Forecast.dropna()
lag_10y1_Forecast=dat3['EURPrices+10_Forecast']
lag_10y1_Forecast=lag_10y1_Forecast.dropna()
lag_11y1_Forecast=dat3['EURPrices+11_Forecast']
lag_11y1_Forecast=lag_11y1_Forecast.dropna()
lag_12y1_Forecast=dat3['EURPrices+12_Forecast']
lag_12y1_Forecast=lag_12y1_Forecast.dropna()
lag_13y1_Forecast=dat3['EURPrices+13_Forecast']
lag_13y1_Forecast=lag_13y1_Forecast.dropna()
lag_14y1_Forecast=dat3['EURPrices+14_Forecast']
lag_14y1_Forecast=lag_14y1_Forecast.dropna()
lag_15y1_Forecast=dat3['EURPrices+15_Forecast']
lag_15y1_Forecast=lag_15y1_Forecast.dropna()
lag_16y1_Forecast=dat3['EURPrices+16_Forecast']
lag_16y1_Forecast=lag_16y1_Forecast.dropna()
lag_17y1_Forecast=dat3['EURPrices+17_Forecast']
lag_17y1_Forecast=lag_17y1_Forecast.dropna()
lag_18y1_Forecast=dat3['EURPrices+18_Forecast']
lag_18y1_Forecast=lag_18y1_Forecast.dropna()
lag_19y1_Forecast=dat3['EURPrices+19_Forecast']
lag_19y1_Forecast=lag_19y1_Forecast.dropna()
lag_20y1_Forecast=dat3['EURPrices+20_Forecast']
lag_20y1_Forecast=lag_20y1_Forecast.dropna()
lag_21y1_Forecast=dat3['EURPrices+21_Forecast']
lag_21y1_Forecast=lag_21y1_Forecast.dropna()
lag_22y1_Forecast=dat3['EURPrices+22_Forecast']
lag_22y1_Forecast=lag_22y1_Forecast.dropna()
lag_23y1_Forecast=dat3['EURPrices+23_Forecast']
lag_23y1_Forecast=lag_23y1_Forecast.dropna()
pred_nn3=pd.concat([lag_0y1_Forecast, lag_1y1_Forecast, lag_2y1_Forecast, lag_3y1_Forecast, lag_4y1_Forecast, 
                    lag_5y1_Forecast, lag_6y1_Forecast, lag_7y1_Forecast, lag_8y1_Forecast, lag_9y1_Forecast,
                    lag_10y1_Forecast, lag_11y1_Forecast, lag_12y1_Forecast, lag_13y1_Forecast, lag_14y1_Forecast,
                    lag_15y1_Forecast, lag_16y1_Forecast, lag_17y1_Forecast, lag_18y1_Forecast, lag_19y1_Forecast,
                    lag_20y1_Forecast, lag_21y1_Forecast, lag_22y1_Forecast, lag_23y1_Forecast], axis=1)


lag_0y1_Forecast=dat4['EURPrices_Forecast']
lag_0y1_Forecast=lag_0y1_Forecast.dropna()
lag_1y1_Forecast=dat4['EURPrices+1_Forecast']
lag_1y1_Forecast=lag_1y1_Forecast.dropna()
lag_2y1_Forecast=dat4['EURPrices+2_Forecast']
lag_2y1_Forecast=lag_2y1_Forecast.dropna()
lag_3y1_Forecast=dat4['EURPrices+3_Forecast']
lag_3y1_Forecast=lag_3y1_Forecast.dropna()
lag_4y1_Forecast=dat4['EURPrices+4_Forecast']
lag_4y1_Forecast=lag_4y1_Forecast.dropna()
lag_5y1_Forecast=dat4['EURPrices+5_Forecast']
lag_5y1_Forecast=lag_5y1_Forecast.dropna()
lag_6y1_Forecast=dat4['EURPrices+6_Forecast']
lag_6y1_Forecast=lag_6y1_Forecast.dropna()
lag_7y1_Forecast=dat4['EURPrices+7_Forecast']
lag_7y1_Forecast=lag_7y1_Forecast.dropna()
lag_8y1_Forecast=dat4['EURPrices+8_Forecast']
lag_8y1_Forecast=lag_8y1_Forecast.dropna()
lag_9y1_Forecast=dat4['EURPrices+9_Forecast']
lag_9y1_Forecast=lag_9y1_Forecast.dropna()
lag_10y1_Forecast=dat4['EURPrices+10_Forecast']
lag_10y1_Forecast=lag_10y1_Forecast.dropna()
lag_11y1_Forecast=dat4['EURPrices+11_Forecast']
lag_11y1_Forecast=lag_11y1_Forecast.dropna()
lag_12y1_Forecast=dat4['EURPrices+12_Forecast']
lag_12y1_Forecast=lag_12y1_Forecast.dropna()
lag_13y1_Forecast=dat4['EURPrices+13_Forecast']
lag_13y1_Forecast=lag_13y1_Forecast.dropna()
lag_14y1_Forecast=dat4['EURPrices+14_Forecast']
lag_14y1_Forecast=lag_14y1_Forecast.dropna()
lag_15y1_Forecast=dat4['EURPrices+15_Forecast']
lag_15y1_Forecast=lag_15y1_Forecast.dropna()
lag_16y1_Forecast=dat4['EURPrices+16_Forecast']
lag_16y1_Forecast=lag_16y1_Forecast.dropna()
lag_17y1_Forecast=dat4['EURPrices+17_Forecast']
lag_17y1_Forecast=lag_17y1_Forecast.dropna()
lag_18y1_Forecast=dat4['EURPrices+18_Forecast']
lag_18y1_Forecast=lag_18y1_Forecast.dropna()
lag_19y1_Forecast=dat4['EURPrices+19_Forecast']
lag_19y1_Forecast=lag_19y1_Forecast.dropna()
lag_20y1_Forecast=dat4['EURPrices+20_Forecast']
lag_20y1_Forecast=lag_20y1_Forecast.dropna()
lag_21y1_Forecast=dat4['EURPrices+21_Forecast']
lag_21y1_Forecast=lag_21y1_Forecast.dropna()
lag_22y1_Forecast=dat4['EURPrices+22_Forecast']
lag_22y1_Forecast=lag_22y1_Forecast.dropna()
lag_23y1_Forecast=dat4['EURPrices+23_Forecast']
lag_23y1_Forecast=lag_23y1_Forecast.dropna()
pred_nn4=pd.concat([lag_0y1_Forecast, lag_1y1_Forecast, lag_2y1_Forecast, lag_3y1_Forecast, lag_4y1_Forecast, 
                    lag_5y1_Forecast, lag_6y1_Forecast, lag_7y1_Forecast, lag_8y1_Forecast, lag_9y1_Forecast,
                    lag_10y1_Forecast, lag_11y1_Forecast, lag_12y1_Forecast, lag_13y1_Forecast, lag_14y1_Forecast,
                    lag_15y1_Forecast, lag_16y1_Forecast, lag_17y1_Forecast, lag_18y1_Forecast, lag_19y1_Forecast,
                    lag_20y1_Forecast, lag_21y1_Forecast, lag_22y1_Forecast, lag_23y1_Forecast], axis=1)

lag_0y1=dat1['EURPrices_Actual']
lag_0y1=lag_0y1.dropna()
lag_1y1=dat1['EURPrices+1_Actual']
lag_1y1=lag_1y1.dropna()
lag_2y1=dat1['EURPrices+2_Actual']
lag_2y1=lag_2y1.dropna()
lag_3y1=dat1['EURPrices+3_Actual']
lag_3y1=lag_3y1.dropna()
lag_4y1=dat1['EURPrices+4_Actual']
lag_4y1=lag_4y1.dropna()
lag_5y1=dat1['EURPrices+5_Actual']
lag_5y1=lag_5y1.dropna()
lag_6y1=dat1['EURPrices+6_Actual']
lag_6y1=lag_6y1.dropna()
lag_7y1=dat1['EURPrices+7_Actual']
lag_7y1=lag_7y1.dropna()
lag_8y1=dat1['EURPrices+8_Actual']
lag_8y1=lag_8y1.dropna()
lag_9y1=dat1['EURPrices+9_Actual']
lag_9y1=lag_9y1.dropna()
lag_10y1=dat1['EURPrices+10_Actual']
lag_10y1=lag_10y1.dropna()
lag_11y1=dat1['EURPrices+11_Actual']
lag_11y1=lag_11y1.dropna()
lag_12y1=dat1['EURPrices+12_Actual']
lag_12y1=lag_12y1.dropna()
lag_13y1=dat1['EURPrices+13_Actual']
lag_13y1=lag_13y1.dropna()
lag_14y1=dat1['EURPrices+14_Actual']
lag_14y1=lag_14y1.dropna()
lag_15y1=dat1['EURPrices+15_Actual']
lag_15y1=lag_15y1.dropna()
lag_16y1=dat1['EURPrices+16_Actual']
lag_16y1=lag_16y1.dropna()
lag_17y1=dat1['EURPrices+17_Actual']
lag_17y1=lag_17y1.dropna()
lag_18y1=dat1['EURPrices+18_Actual']
lag_18y1=lag_18y1.dropna()
lag_19y1=dat1['EURPrices+19_Actual']
lag_19y1=lag_19y1.dropna()
lag_20y1=dat1['EURPrices+20_Actual']
lag_20y1=lag_20y1.dropna()
lag_21y1=dat1['EURPrices+21_Actual']
lag_21y1=lag_21y1.dropna()
lag_22y1=dat1['EURPrices+22_Actual']
lag_22y1=lag_22y1.dropna()
lag_23y1=dat1['EURPrices+23_Actual']
lag_23y1=lag_23y1.dropna()
Y_test1=pd.concat([lag_0y1, lag_1y1, lag_2y1, lag_3y1, lag_4y1, lag_5y1, lag_6y1, lag_7y1,lag_8y1, lag_9y1,
                   lag_10y1, lag_11y1, lag_12y1, lag_13y1, lag_14y1, lag_15y1, lag_16y1, lag_17y1, lag_18y1,
                   lag_19y1, lag_20y1, lag_21y1, lag_22y1, lag_23y1], axis=1)

lag_0y1=dat2['EURPrices_Actual']
lag_0y1=lag_0y1.dropna()
lag_1y1=dat2['EURPrices+1_Actual']
lag_1y1=lag_1y1.dropna()
lag_2y1=dat2['EURPrices+2_Actual']
lag_2y1=lag_2y1.dropna()
lag_3y1=dat2['EURPrices+3_Actual']
lag_3y1=lag_3y1.dropna()
lag_4y1=dat2['EURPrices+4_Actual']
lag_4y1=lag_4y1.dropna()
lag_5y1=dat2['EURPrices+5_Actual']
lag_5y1=lag_5y1.dropna()
lag_6y1=dat2['EURPrices+6_Actual']
lag_6y1=lag_6y1.dropna()
lag_7y1=dat2['EURPrices+7_Actual']
lag_7y1=lag_7y1.dropna()
lag_8y1=dat2['EURPrices+8_Actual']
lag_8y1=lag_8y1.dropna()
lag_9y1=dat2['EURPrices+9_Actual']
lag_9y1=lag_9y1.dropna()
lag_10y1=dat2['EURPrices+10_Actual']
lag_10y1=lag_10y1.dropna()
lag_11y1=dat2['EURPrices+11_Actual']
lag_11y1=lag_11y1.dropna()
lag_12y1=dat2['EURPrices+12_Actual']
lag_12y1=lag_12y1.dropna()
lag_13y1=dat2['EURPrices+13_Actual']
lag_13y1=lag_13y1.dropna()
lag_14y1=dat2['EURPrices+14_Actual']
lag_14y1=lag_14y1.dropna()
lag_15y1=dat2['EURPrices+15_Actual']
lag_15y1=lag_15y1.dropna()
lag_16y1=dat2['EURPrices+16_Actual']
lag_16y1=lag_16y1.dropna()
lag_17y1=dat2['EURPrices+17_Actual']
lag_17y1=lag_17y1.dropna()
lag_18y1=dat2['EURPrices+18_Actual']
lag_18y1=lag_18y1.dropna()
lag_19y1=dat2['EURPrices+19_Actual']
lag_19y1=lag_19y1.dropna()
lag_20y1=dat2['EURPrices+20_Actual']
lag_20y1=lag_20y1.dropna()
lag_21y1=dat2['EURPrices+21_Actual']
lag_21y1=lag_21y1.dropna()
lag_22y1=dat2['EURPrices+22_Actual']
lag_22y1=lag_22y1.dropna()
lag_23y1=dat2['EURPrices+23_Actual']
lag_23y1=lag_23y1.dropna()
Y_test2=pd.concat([lag_0y1, lag_1y1, lag_2y1, lag_3y1, lag_4y1, lag_5y1, lag_6y1, lag_7y1,lag_8y1, lag_9y1,
                   lag_10y1, lag_11y1, lag_12y1, lag_13y1, lag_14y1, lag_15y1, lag_16y1, lag_17y1, lag_18y1,
                   lag_19y1, lag_20y1, lag_21y1, lag_22y1, lag_23y1], axis=1)

lag_0y1=dat3['EURPrices_Actual']
lag_0y1=lag_0y1.dropna()
lag_1y1=dat3['EURPrices+1_Actual']
lag_1y1=lag_1y1.dropna()
lag_2y1=dat3['EURPrices+2_Actual']
lag_2y1=lag_2y1.dropna()
lag_3y1=dat3['EURPrices+3_Actual']
lag_3y1=lag_3y1.dropna()
lag_4y1=dat3['EURPrices+4_Actual']
lag_4y1=lag_4y1.dropna()
lag_5y1=dat3['EURPrices+5_Actual']
lag_5y1=lag_5y1.dropna()
lag_6y1=dat3['EURPrices+6_Actual']
lag_6y1=lag_6y1.dropna()
lag_7y1=dat3['EURPrices+7_Actual']
lag_7y1=lag_7y1.dropna()
lag_8y1=dat3['EURPrices+8_Actual']
lag_8y1=lag_8y1.dropna()
lag_9y1=dat3['EURPrices+9_Actual']
lag_9y1=lag_9y1.dropna()
lag_10y1=dat3['EURPrices+10_Actual']
lag_10y1=lag_10y1.dropna()
lag_11y1=dat3['EURPrices+11_Actual']
lag_11y1=lag_11y1.dropna()
lag_12y1=dat3['EURPrices+12_Actual']
lag_12y1=lag_12y1.dropna()
lag_13y1=dat3['EURPrices+13_Actual']
lag_13y1=lag_13y1.dropna()
lag_14y1=dat3['EURPrices+14_Actual']
lag_14y1=lag_14y1.dropna()
lag_15y1=dat3['EURPrices+15_Actual']
lag_15y1=lag_15y1.dropna()
lag_16y1=dat3['EURPrices+16_Actual']
lag_16y1=lag_16y1.dropna()
lag_17y1=dat3['EURPrices+17_Actual']
lag_17y1=lag_17y1.dropna()
lag_18y1=dat3['EURPrices+18_Actual']
lag_18y1=lag_18y1.dropna()
lag_19y1=dat3['EURPrices+19_Actual']
lag_19y1=lag_19y1.dropna()
lag_20y1=dat3['EURPrices+20_Actual']
lag_20y1=lag_20y1.dropna()
lag_21y1=dat3['EURPrices+21_Actual']
lag_21y1=lag_21y1.dropna()
lag_22y1=dat3['EURPrices+22_Actual']
lag_22y1=lag_22y1.dropna()
lag_23y1=dat3['EURPrices+23_Actual']
lag_23y1=lag_23y1.dropna()
Y_test3=pd.concat([lag_0y1, lag_1y1, lag_2y1, lag_3y1, lag_4y1, lag_5y1, lag_6y1, lag_7y1,lag_8y1, lag_9y1,
                   lag_10y1, lag_11y1, lag_12y1, lag_13y1, lag_14y1, lag_15y1, lag_16y1, lag_17y1, lag_18y1,
                   lag_19y1, lag_20y1, lag_21y1, lag_22y1, lag_23y1], axis=1)

lag_0y1=dat4['EURPrices_Actual']
lag_0y1=lag_0y1.dropna()
lag_1y1=dat4['EURPrices+1_Actual']
lag_1y1=lag_1y1.dropna()
lag_2y1=dat4['EURPrices+2_Actual']
lag_2y1=lag_2y1.dropna()
lag_3y1=dat4['EURPrices+3_Actual']
lag_3y1=lag_3y1.dropna()
lag_4y1=dat4['EURPrices+4_Actual']
lag_4y1=lag_4y1.dropna()
lag_5y1=dat4['EURPrices+5_Actual']
lag_5y1=lag_5y1.dropna()
lag_6y1=dat4['EURPrices+6_Actual']
lag_6y1=lag_6y1.dropna()
lag_7y1=dat4['EURPrices+7_Actual']
lag_7y1=lag_7y1.dropna()
lag_8y1=dat4['EURPrices+8_Actual']
lag_8y1=lag_8y1.dropna()
lag_9y1=dat4['EURPrices+9_Actual']
lag_9y1=lag_9y1.dropna()
lag_10y1=dat4['EURPrices+10_Actual']
lag_10y1=lag_10y1.dropna()
lag_11y1=dat4['EURPrices+11_Actual']
lag_11y1=lag_11y1.dropna()
lag_12y1=dat4['EURPrices+12_Actual']
lag_12y1=lag_12y1.dropna()
lag_13y1=dat4['EURPrices+13_Actual']
lag_13y1=lag_13y1.dropna()
lag_14y1=dat4['EURPrices+14_Actual']
lag_14y1=lag_14y1.dropna()
lag_15y1=dat4['EURPrices+15_Actual']
lag_15y1=lag_15y1.dropna()
lag_16y1=dat4['EURPrices+16_Actual']
lag_16y1=lag_16y1.dropna()
lag_17y1=dat4['EURPrices+17_Actual']
lag_17y1=lag_17y1.dropna()
lag_18y1=dat4['EURPrices+18_Actual']
lag_18y1=lag_18y1.dropna()
lag_19y1=dat4['EURPrices+19_Actual']
lag_19y1=lag_19y1.dropna()
lag_20y1=dat4['EURPrices+20_Actual']
lag_20y1=lag_20y1.dropna()
lag_21y1=dat4['EURPrices+21_Actual']
lag_21y1=lag_21y1.dropna()
lag_22y1=dat4['EURPrices+22_Actual']
lag_22y1=lag_22y1.dropna()
lag_23y1=dat4['EURPrices+23_Actual']
lag_23y1=lag_23y1.dropna()
Y_test4=pd.concat([lag_0y1, lag_1y1, lag_2y1, lag_3y1, lag_4y1, lag_5y1, lag_6y1, lag_7y1,lag_8y1, lag_9y1,
                   lag_10y1, lag_11y1, lag_12y1, lag_13y1, lag_14y1, lag_15y1, lag_16y1, lag_17y1, lag_18y1,
                   lag_19y1, lag_20y1, lag_21y1, lag_22y1, lag_23y1], axis=1)

print(Y_test1.shape)
print(pred_nn1.shape)
print(Y_test2.shape)
print(pred_nn2.shape)
print(Y_test3.shape)
print(pred_nn3.shape)
print(Y_test4.shape)
print(pred_nn4.shape)


mse1= mean_squared_error(Y_test1, pred_nn1)
rmse1 = sqrt(mse1)
mae1 = mean_absolute_error(Y_test1, pred_nn1)
smape1 = sMAPE(Y_test1, pred_nn1)*100
Error_1 = pd.DataFrame([mse1, rmse1, mae1, smape1]).T

mse2 = mean_squared_error(Y_test2, pred_nn2)
rmse2 = sqrt(mse2)
mae2 = mean_absolute_error(Y_test2, pred_nn2)
smape2 = sMAPE(Y_test2, pred_nn2)*100
Error_2 = pd.DataFrame([mse2, rmse2, mae2, smape2]).T

mse3 = mean_squared_error(Y_test3, pred_nn3)
rmse3 = sqrt(mse3)
mae3 = mean_absolute_error(Y_test3, pred_nn3)
smape3 = sMAPE(Y_test3, pred_nn3)*100
Error_3 = pd.DataFrame([mse3, rmse3, mae3, smape3]).T

mse4 = mean_squared_error(Y_test4, pred_nn4)
rmse4 = sqrt(mse4)
mae4 = mean_absolute_error(Y_test4, pred_nn4)
smape4 = sMAPE(Y_test4, pred_nn4)*100
Error_4 = pd.DataFrame([mse4, rmse4, mae4, smape4]).T

YY_test=pd.concat([Y_test1, Y_test2, Y_test3, Y_test4], axis=0)
PPreds=pd.concat([pred_nn1,pred_nn2, pred_nn3, pred_nn4], axis=0)
mse = mean_squared_error(YY_test, PPreds)
rmse = sqrt(mse)
mae = mean_absolute_error(YY_test, PPreds)
smape = sMAPE(YY_test, PPreds)*100
Erroru = pd.DataFrame([mse, rmse, mae, smape]).T
print(Error_1)
print(Error_2)
print(Error_3)
print(Error_4)
print(Erroru)

aa=pd.DataFrame(PPreds['EURPrices_Forecast'])
aa=aa.reset_index(drop=True)
bb=pd.DataFrame(YY_test['EURPrices_Actual'])
bb=bb.reset_index(drop=True)

# figure(figsize = (14, 8), dpi = 90)
# plt.plot(aa, color='green', label='LEAR predictions')
# plt.plot(bb, color='blue', label='BM prices', alpha=0.2)
# plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=18)
# plt.ylabel('€/MWh', fontsize=18)
# plt.title("LEAR Forecast of BM prices", fontsize=18)
# # plt.xlim([0, 1000])
# plt.ylim([-100,300])
# plt.legend()
# plt.savefig('LEAR.png', transparent=False, format="jpg")


figure(figsize = (14, 8), dpi = 90)
plt.plot(aa, color='green', label='DNN DAM predictions')
plt.plot(bb, color='blue', label='DAM prices', alpha=0.2)
plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=18)
plt.ylabel('€/MWh', fontsize=18)
plt.title("Deep Neural Network Forecast of DAM prices", fontsize=18)
# plt.xlim([0, 4400])
# plt.ylim([-20,50])
plt.legend()
# plt.savefig('DAM_DNN.png', transparent=False, format="jpg")
# Out:
# (92, 24)
# (92, 24)
# (91, 24)
# (91, 24)
# (90, 24)
# (90, 24)
# (92, 24)
# (92, 24)
#           0         1         2          3
# 0  31.90113  5.648109  4.056946  21.288064
#             0          1         2          3
# 0  160.786833  12.680175  7.584501  22.256654
#             0          1         2          3
# 0  184.091276  13.568024  6.967555  14.609575
#             0          1          2          3
# 0  390.601657  19.763645  10.742856  17.836397
#             0          1         2          3
# 0  191.972803  13.855425  7.339319  19.012788

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter,AutoMinorLocator
import matplotlib as mpl
plt.style.use('plot_style.txt')
#=========================================================== # Directory and filename; style file open #=========================================================== # Change to the directory which contains the current script 
dirFile = os.path.dirname(os.path.join('YourDirHere',
                          'NicePlotProductivity.py'))
# Load style file plt.style.use(os.path.join(dirFile, 'PaperDoubleFig.mplstyle'))
# Make some style choices for plotting 
colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061']
dashesStyles = [[3,1],
            [1000,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1]]
aa=pd.DataFrame(PPreds['EURPrices_Forecast'])
aa=aa.reset_index(drop=True)
bb=pd.DataFrame(YY_test['EURPrices_Actual'])
bb=bb.reset_index(drop=True)
DAM_d=pd.DataFrame(YY_test['EURPrices_Actual'])
DAM_d=DAM_d.reset_index(drop=True)
figure(figsize = (14, 8), dpi = 90)
plt.plot(aa, color='red', label='SH DNN DAM predictions')
plt.plot(bb, color='blue', label='DAM prices', alpha=0.2)
plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=22)
plt.ylabel('€/MWh', fontsize=22)
plt.xlim([-20, 380])
# plt.ylim([-200,600])
plt.legend( fontsize=20)
plt.savefig('DAM_DNN.png', transparent=False, format="jpg")

# %%
date_format="%m/%d/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
# dat = pd.read_csv("C:/Users/coconnor/Documents/BM_data.csv", index_col="SettlementPeriod", parse_dates=True, date_parser=date_parse)
dat1 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-10.csv")
dat2 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-13.csv")
dat3 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-16.csv")
dat4 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-19.csv")

dat1=pd.DataFrame(dat1)
dat2=pd.DataFrame(dat2)
dat3=pd.DataFrame(dat3)
dat4=pd.DataFrame(dat4)

# dat1 = dat1.iloc[::3, :]
# dat2 = dat2.iloc[::3, :]
# dat3 = dat3.iloc[::3, :]
# dat4 = dat4.iloc[::3, :]

# %%
dat1.shape
# Out:
# (834, 33)

# %%
date_format="%m/%d/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
# dat = pd.read_csv("C:/Users/coconnor/Documents/BM_data.csv", index_col="SettlementPeriod", parse_dates=True, date_parser=date_parse)
dat1 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-10.csv")
dat2 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-13.csv")
dat3 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-16.csv")
dat4 = pd.read_csv("/home/ciaran/Documents/BM_SH_DNN_results/BM_results_SH_1-19.csv")

dat1=pd.DataFrame(dat1)
dat2=pd.DataFrame(dat2)
dat3=pd.DataFrame(dat3)
dat4=pd.DataFrame(dat4)



lag_2y1_Forecast=dat1['lag_2y_Forecast']
lag_2y1_Forecast=lag_2y1_Forecast.dropna()
lag_3y1_Forecast=dat1['lag_3y_Forecast']
lag_3y1_Forecast=lag_3y1_Forecast.dropna()
lag_4y1_Forecast=dat1['lag_4y_Forecast']
lag_4y1_Forecast=lag_4y1_Forecast.dropna()
lag_5y1_Forecast=dat1['lag_5y_Forecast']
lag_5y1_Forecast=lag_5y1_Forecast.dropna()
lag_6y1_Forecast=dat1['lag_6y_Forecast']
lag_6y1_Forecast=lag_6y1_Forecast.dropna()
lag_7y1_Forecast=dat1['lag_7y_Forecast']
lag_7y1_Forecast=lag_7y1_Forecast.dropna()
lag_8y1_Forecast=dat1['lag_8y_Forecast']
lag_8y1_Forecast=lag_8y1_Forecast.dropna()
lag_9y1_Forecast=dat1['lag_9y_Forecast']
lag_9y1_Forecast=lag_9y1_Forecast.dropna()
lag_10y1_Forecast=dat1['lag_10y_Forecast']
lag_10y1_Forecast=lag_10y1_Forecast.dropna()
lag_11y1_Forecast=dat1['lag_11y_Forecast']
lag_11y1_Forecast=lag_11y1_Forecast.dropna()
lag_12y1_Forecast=dat1['lag_12y_Forecast']
lag_12y1_Forecast=lag_12y1_Forecast.dropna()
lag_13y1_Forecast=dat1['lag_13y_Forecast']
lag_13y1_Forecast=lag_13y1_Forecast.dropna()
lag_14y1_Forecast=dat1['lag_14y_Forecast']
lag_14y1_Forecast=lag_14y1_Forecast.dropna()
lag_15y1_Forecast=dat1['lag_15y_Forecast']
lag_15y1_Forecast=lag_15y1_Forecast.dropna()
lag_16y1_Forecast=dat1['lag_16y_Forecast']
lag_16y1_Forecast=lag_16y1_Forecast.dropna()
lag_17y1_Forecast=dat1['lag_17y_Forecast']
lag_17y1_Forecast=lag_17y1_Forecast.dropna()
pred_nn1=pd.concat([lag_2y1_Forecast, lag_3y1_Forecast, lag_4y1_Forecast, lag_5y1_Forecast, lag_6y1_Forecast, lag_7y1_Forecast,
               lag_8y1_Forecast, lag_9y1_Forecast, lag_10y1_Forecast, lag_11y1_Forecast, lag_12y1_Forecast, 
               lag_13y1_Forecast, lag_14y1_Forecast, lag_15y1_Forecast, lag_16y1_Forecast, lag_17y1_Forecast], axis=1)
lag_2y2_Forecast=dat2['lag_2y_Forecast']
lag_2y2_Forecast=lag_2y2_Forecast.dropna()
lag_3y2_Forecast=dat2['lag_3y_Forecast']
lag_3y2_Forecast=lag_3y2_Forecast.dropna()
lag_4y2_Forecast=dat2['lag_4y_Forecast']
lag_4y2_Forecast=lag_4y2_Forecast.dropna()
lag_5y2_Forecast=dat2['lag_5y_Forecast']
lag_5y2_Forecast=lag_5y2_Forecast.dropna()
lag_6y2_Forecast=dat2['lag_6y_Forecast']
lag_6y2_Forecast=lag_6y2_Forecast.dropna()
lag_7y2_Forecast=dat2['lag_7y_Forecast']
lag_7y2_Forecast=lag_7y2_Forecast.dropna()
lag_8y2_Forecast=dat2['lag_8y_Forecast']
lag_8y2_Forecast=lag_8y2_Forecast.dropna()
lag_9y2_Forecast=dat2['lag_9y_Forecast']
lag_9y2_Forecast=lag_9y2_Forecast.dropna()
lag_10y2_Forecast=dat2['lag_10y_Forecast']
lag_10y2_Forecast=lag_10y2_Forecast.dropna()
lag_11y2_Forecast=dat2['lag_11y_Forecast']
lag_11y2_Forecast=lag_11y2_Forecast.dropna()
lag_12y2_Forecast=dat2['lag_12y_Forecast']
lag_12y2_Forecast=lag_12y2_Forecast.dropna()
lag_13y2_Forecast=dat2['lag_13y_Forecast']
lag_13y2_Forecast=lag_13y2_Forecast.dropna()
lag_14y2_Forecast=dat2['lag_14y_Forecast']
lag_14y2_Forecast=lag_14y2_Forecast.dropna()
lag_15y2_Forecast=dat2['lag_15y_Forecast']
lag_15y2_Forecast=lag_15y2_Forecast.dropna()
lag_16y2_Forecast=dat2['lag_16y_Forecast']
lag_16y2_Forecast=lag_16y2_Forecast.dropna()
lag_17y2_Forecast=dat2['lag_17y_Forecast']
lag_17y2_Forecast=lag_17y2_Forecast.dropna()
pred_nn2=pd.concat([lag_2y2_Forecast, lag_3y2_Forecast, lag_4y2_Forecast, lag_5y2_Forecast, lag_6y2_Forecast, lag_7y2_Forecast,
               lag_8y2_Forecast, lag_9y2_Forecast, lag_10y2_Forecast, lag_11y2_Forecast, lag_12y2_Forecast, 
               lag_13y2_Forecast, lag_14y2_Forecast, lag_15y2_Forecast, lag_16y2_Forecast, lag_17y2_Forecast], axis=1)
lag_2y3_Forecast=dat3['lag_2y_Forecast']
lag_2y3_Forecast=lag_2y3_Forecast.dropna()
lag_3y3_Forecast=dat3['lag_3y_Forecast']
lag_3y3_Forecast=lag_3y3_Forecast.dropna()
lag_4y3_Forecast=dat3['lag_4y_Forecast']
lag_4y3_Forecast=lag_4y3_Forecast.dropna()
lag_5y3_Forecast=dat3['lag_5y_Forecast']
lag_5y3_Forecast=lag_5y3_Forecast.dropna()
lag_6y3_Forecast=dat3['lag_6y_Forecast']
lag_6y3_Forecast=lag_6y3_Forecast.dropna()
lag_7y3_Forecast=dat3['lag_7y_Forecast']
lag_7y3_Forecast=lag_7y3_Forecast.dropna()
lag_8y3_Forecast=dat3['lag_8y_Forecast']
lag_8y3_Forecast=lag_8y3_Forecast.dropna()
lag_9y3_Forecast=dat3['lag_9y_Forecast']
lag_9y3_Forecast=lag_9y3_Forecast.dropna()
lag_10y3_Forecast=dat3['lag_10y_Forecast']
lag_10y3_Forecast=lag_10y3_Forecast.dropna()
lag_11y3_Forecast=dat3['lag_11y_Forecast']
lag_11y3_Forecast=lag_11y3_Forecast.dropna()
lag_12y3_Forecast=dat3['lag_12y_Forecast']
lag_12y3_Forecast=lag_12y3_Forecast.dropna()
lag_13y3_Forecast=dat3['lag_13y_Forecast']
lag_13y3_Forecast=lag_13y3_Forecast.dropna()
lag_14y3_Forecast=dat3['lag_14y_Forecast']
lag_14y3_Forecast=lag_14y3_Forecast.dropna()
lag_15y3_Forecast=dat3['lag_15y_Forecast']
lag_15y3_Forecast=lag_15y3_Forecast.dropna()
lag_16y3_Forecast=dat3['lag_16y_Forecast']
lag_16y3_Forecast=lag_16y3_Forecast.dropna()
lag_17y3_Forecast=dat3['lag_17y_Forecast']
lag_17y3_Forecast=lag_17y3_Forecast.dropna()
pred_nn3=pd.concat([lag_2y3_Forecast, lag_3y3_Forecast, lag_4y3_Forecast, lag_5y3_Forecast, lag_6y3_Forecast, lag_7y3_Forecast,
               lag_8y3_Forecast, lag_9y3_Forecast, lag_10y3_Forecast, lag_11y3_Forecast, lag_12y3_Forecast, 
               lag_13y3_Forecast, lag_14y3_Forecast, lag_15y3_Forecast, lag_16y3_Forecast, lag_17y3_Forecast], axis=1)
lag_2y4_Forecast=dat4['lag_2y_Forecast']
lag_2y4_Forecast=lag_2y4_Forecast.dropna()
lag_3y4_Forecast=dat4['lag_3y_Forecast']
lag_3y4_Forecast=lag_3y4_Forecast.dropna()
lag_4y4_Forecast=dat4['lag_4y_Forecast']
lag_4y4_Forecast=lag_4y4_Forecast.dropna()
lag_5y4_Forecast=dat4['lag_5y_Forecast']
lag_5y4_Forecast=lag_5y4_Forecast.dropna()
lag_6y4_Forecast=dat4['lag_6y_Forecast']
lag_6y4_Forecast=lag_6y4_Forecast.dropna()
lag_7y4_Forecast=dat4['lag_7y_Forecast']
lag_7y4_Forecast=lag_7y4_Forecast.dropna()
lag_8y4_Forecast=dat4['lag_8y_Forecast']
lag_8y4_Forecast=lag_8y4_Forecast.dropna()
lag_9y4_Forecast=dat4['lag_9y_Forecast']
lag_9y4_Forecast=lag_9y4_Forecast.dropna()
lag_10y4_Forecast=dat4['lag_10y_Forecast']
lag_10y4_Forecast=lag_10y4_Forecast.dropna()
lag_11y4_Forecast=dat4['lag_11y_Forecast']
lag_11y4_Forecast=lag_11y4_Forecast.dropna()
lag_12y4_Forecast=dat4['lag_12y_Forecast']
lag_12y4_Forecast=lag_12y4_Forecast.dropna()
lag_13y4_Forecast=dat4['lag_13y_Forecast']
lag_13y4_Forecast=lag_13y4_Forecast.dropna()
lag_14y4_Forecast=dat4['lag_14y_Forecast']
lag_14y4_Forecast=lag_14y4_Forecast.dropna()
lag_15y4_Forecast=dat4['lag_15y_Forecast']
lag_15y4_Forecast=lag_15y4_Forecast.dropna()
lag_16y4_Forecast=dat4['lag_16y_Forecast']
lag_16y4_Forecast=lag_16y4_Forecast.dropna()
lag_17y4_Forecast=dat4['lag_17y_Forecast']
lag_17y4_Forecast=lag_17y4_Forecast.dropna()
pred_nn4=pd.concat([lag_2y4_Forecast, lag_3y4_Forecast, lag_4y4_Forecast, lag_5y4_Forecast, lag_6y4_Forecast, lag_7y4_Forecast,
               lag_8y4_Forecast, lag_9y4_Forecast, lag_10y4_Forecast, lag_11y4_Forecast, lag_12y4_Forecast, 
               lag_13y4_Forecast, lag_14y4_Forecast, lag_15y4_Forecast, lag_16y4_Forecast, lag_17y4_Forecast], axis=1)

lag_2y1=dat1['lag_2y']
lag_2y1=lag_2y1.dropna()
lag_3y1=dat1['lag_3y']
lag_3y1=lag_3y1.dropna()
lag_4y1=dat1['lag_4y']
lag_4y1=lag_4y1.dropna()
lag_5y1=dat1['lag_5y']
lag_5y1=lag_5y1.dropna()
lag_6y1=dat1['lag_6y']
lag_6y1=lag_6y1.dropna()
lag_7y1=dat1['lag_7y']
lag_7y1=lag_7y1.dropna()
lag_8y1=dat1['lag_8y']
lag_8y1=lag_8y1.dropna()
lag_9y1=dat1['lag_9y']
lag_9y1=lag_9y1.dropna()
lag_10y1=dat1['lag_10y']
lag_10y1=lag_10y1.dropna()
lag_11y1=dat1['lag_11y']
lag_11y1=lag_11y1.dropna()
lag_12y1=dat1['lag_12y']
lag_12y1=lag_12y1.dropna()
lag_13y1=dat1['lag_13y']
lag_13y1=lag_13y1.dropna()
lag_14y1=dat1['lag_14y']
lag_14y1=lag_14y1.dropna()
lag_15y1=dat1['lag_15y']
lag_15y1=lag_15y1.dropna()
lag_16y1=dat1['lag_16y']
lag_16y1=lag_16y1.dropna()
lag_17y1=dat1['lag_17y']
lag_17y1=lag_17y1.dropna()
Y_test1=pd.concat([lag_2y1, lag_3y1, lag_4y1, lag_5y1, lag_6y1, lag_7y1,lag_8y1, lag_9y1, lag_10y1, lag_11y1, lag_12y1, 
               lag_13y1, lag_14y1, lag_15y1, lag_16y1, lag_17y1], axis=1)
lag_2y2=dat2['lag_2y']
lag_2y2=lag_2y2.dropna()
lag_3y2=dat2['lag_3y']
lag_3y2=lag_3y2.dropna()
lag_4y2=dat2['lag_4y']
lag_4y2=lag_4y2.dropna()
lag_5y2=dat2['lag_5y']
lag_5y2=lag_5y2.dropna()
lag_6y2=dat2['lag_6y']
lag_6y2=lag_6y2.dropna()
lag_7y2=dat2['lag_7y']
lag_7y2=lag_7y2.dropna()
lag_8y2=dat2['lag_8y']
lag_8y2=lag_8y2.dropna()
lag_9y2=dat2['lag_9y']
lag_9y2=lag_9y2.dropna()
lag_10y2=dat2['lag_10y']
lag_10y2=lag_10y2.dropna()
lag_11y2=dat2['lag_11y']
lag_11y2=lag_11y2.dropna()
lag_12y2=dat2['lag_12y']
lag_12y2=lag_12y2.dropna()
lag_13y2=dat2['lag_13y']
lag_13y2=lag_13y2.dropna()
lag_14y2=dat2['lag_14y']
lag_14y2=lag_14y2.dropna()
lag_15y2=dat2['lag_15y']
lag_15y2=lag_15y2.dropna()
lag_16y2=dat2['lag_16y']
lag_16y2=lag_16y2.dropna()
lag_17y2=dat2['lag_17y']
lag_17y2=lag_17y2.dropna()
Y_test2=pd.concat([lag_2y2, lag_3y2, lag_4y2, lag_5y2, lag_6y2, lag_7y2, lag_8y2, lag_9y2, lag_10y2, lag_11y2, lag_12y2, 
               lag_13y2, lag_14y2, lag_15y2, lag_16y2, lag_17y2], axis=1)
lag_2y3=dat3['lag_2y']
lag_2y3=lag_2y3.dropna()
lag_3y3=dat3['lag_3y']
lag_3y3=lag_3y3.dropna()
lag_4y3=dat3['lag_4y']
lag_4y3=lag_4y3.dropna()
lag_5y3=dat3['lag_5y']
lag_5y3=lag_5y3.dropna()
lag_6y3=dat3['lag_6y']
lag_6y3=lag_6y3.dropna()
lag_7y3=dat3['lag_7y']
lag_7y3=lag_7y3.dropna()
lag_8y3=dat3['lag_8y']
lag_8y3=lag_8y3.dropna()
lag_9y3=dat3['lag_9y']
lag_9y3=lag_9y3.dropna()
lag_10y3=dat3['lag_10y']
lag_10y3=lag_10y3.dropna()
lag_11y3=dat3['lag_11y']
lag_11y3=lag_11y3.dropna()
lag_12y3=dat3['lag_12y']
lag_12y3=lag_12y3.dropna()
lag_13y3=dat3['lag_13y']
lag_13y3=lag_13y3.dropna()
lag_14y3=dat3['lag_14y']
lag_14y3=lag_14y3.dropna()
lag_15y3=dat3['lag_15y']
lag_15y3=lag_15y3.dropna()
lag_16y3=dat3['lag_16y']
lag_16y3=lag_16y3.dropna()
lag_17y3=dat3['lag_17y']
lag_17y3=lag_17y3.dropna()
Y_test3=pd.concat([lag_2y3, lag_3y3, lag_4y3, lag_5y3, lag_6y3, lag_7y3, lag_8y3, lag_9y3, lag_10y3, lag_11y3, lag_12y3, 
               lag_13y3, lag_14y3, lag_15y3, lag_16y3, lag_17y3], axis=1)
lag_2y4=dat4['lag_2y']
lag_2y4=lag_2y4.dropna()
lag_3y4=dat4['lag_3y']
lag_3y4=lag_3y4.dropna()
lag_4y4=dat4['lag_4y']
lag_4y4=lag_4y4.dropna()
lag_5y4=dat4['lag_5y']
lag_5y4=lag_5y4.dropna()
lag_6y4=dat4['lag_6y']
lag_6y4=lag_6y4.dropna()
lag_7y4=dat4['lag_7y']
lag_7y4=lag_7y4.dropna()
lag_8y4=dat4['lag_8y']
lag_8y4=lag_8y4.dropna()
lag_9y4=dat4['lag_9y']
lag_9y4=lag_9y4.dropna()
lag_10y4=dat4['lag_10y']
lag_10y4=lag_10y4.dropna()
lag_11y4=dat4['lag_11y']
lag_11y4=lag_11y4.dropna()
lag_12y4=dat4['lag_12y']
lag_12y4=lag_12y4.dropna()
lag_13y4=dat4['lag_13y']
lag_13y4=lag_13y4.dropna()
lag_14y4=dat4['lag_14y']
lag_14y4=lag_14y4.dropna()
lag_15y4=dat4['lag_15y']
lag_15y4=lag_15y4.dropna()
lag_16y4=dat4['lag_16y']
lag_16y4=lag_16y4.dropna()
lag_17y4=dat4['lag_17y']
lag_17y4=lag_17y4.dropna()
Y_test4=pd.concat([lag_2y4, lag_3y4, lag_4y4, lag_5y4, lag_6y4, lag_7y4, lag_8y4, lag_9y4, lag_10y4, lag_11y4, lag_12y4, 
               lag_13y4, lag_14y4, lag_15y4, lag_16y4, lag_17y4], axis=1)
np.errstate(divide='ignore',invalid='ignore')
mse1= mean_squared_error(Y_test1, pred_nn1)
rmse1 = sqrt(mse1)
mae1 = mean_absolute_error(Y_test1, pred_nn1)
mape1 = MAPE(Y_test1, pred_nn1)*100
smape1 = sMAPE(Y_test1, pred_nn1)*100
Error_1 = pd.DataFrame([mse1, rmse1, mae1, smape1]).T

mse2 = mean_squared_error(Y_test2, pred_nn2)
rmse2 = sqrt(mse2)
mae2 = mean_absolute_error(Y_test2, pred_nn2)
mape2 = MAPE(Y_test2, pred_nn2)*100
smape2 = sMAPE(Y_test2, pred_nn2)*100
Error_2 = pd.DataFrame([mse2, rmse2, mae2, smape2]).T

mse3 = mean_squared_error(Y_test3, pred_nn3)
rmse3 = sqrt(mse3)
mae3 = mean_absolute_error(Y_test3, pred_nn3)
mape3 = MAPE(Y_test3, pred_nn3)*100
smape3 = sMAPE(Y_test3, pred_nn3)*100
Error_3 = pd.DataFrame([mse3, rmse3, mae3, smape3]).T

mse4 = mean_squared_error(Y_test4, pred_nn4)
rmse4 = sqrt(mse4)
mae4 = mean_absolute_error(Y_test4, pred_nn4)
mape4 = MAPE(Y_test4, pred_nn4)*100
smape4 = sMAPE(Y_test4, pred_nn4)*100
Error_4 = pd.DataFrame([mse4, rmse4, mae4, smape4]).T

YY_test=pd.concat([Y_test1, Y_test2, Y_test3, Y_test4], axis=0)
PPreds=pd.concat([pred_nn1,pred_nn2, pred_nn3, pred_nn4], axis=0)
mse = mean_squared_error(YY_test, PPreds)
rmse = sqrt(mse)
mae = mean_absolute_error(YY_test, PPreds)
mape = MAPE(YY_test, PPreds)*100
smape = sMAPE(YY_test, PPreds)*100
Erroru = pd.DataFrame([mse, rmse, mae, smape]).T
print(pred_nn1.shape)
print(pred_nn2.shape)
print(pred_nn3.shape)
print(pred_nn4.shape)

print(Y_test1.shape)
print(Y_test2.shape)
print(Y_test3.shape)
print(Y_test4.shape)
print(Error_1)
print(Error_2)
print(Error_3)
print(Error_4)
print(Erroru)

aa=pd.DataFrame(PPreds['lag_2y_Forecast'])
aa=aa.reset_index(drop=True)
bb=YY_test['lag_2y']
bb=bb.reset_index(drop=True)

figure(figsize = (14, 8), dpi = 90)
plt.plot(aa, color='green', label='DNN predictions')
plt.plot(bb, color='blue', label='BM prices', alpha=0.2)
plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=18)
plt.ylabel('€/MWh', fontsize=18)
plt.title("Deep Neural Network Forecast of BM prices", fontsize=18)
# plt.xlim([0, 1000])
plt.ylim([-100,300])
plt.legend()
# plt.savefig('SH_DNN.png', transparent=False, format="jpg")
# Out:
# (278, 16)
# (273, 16)
# (270, 16)
# (276, 16)
# (278, 16)
# (273, 16)
# (270, 16)
# (276, 16)
#              0          1         2          3
# 0  1954.692339  44.211903  27.11212  73.828637
#              0         1          2          3
# 0  3035.277217  55.09335  34.678972  76.987868
#              0          1          2          3
# 0  6395.972936  79.974827  44.168833  73.496919
#              0          1          2          3
# 0  4023.492828  63.431008  43.905986  59.011703
#              0         1          2         3
# 0  3837.221389  61.94531  37.418565  70.80533

# %%
bb.shape
# Out:
# (1097,)

# %%
bb=YY_test['lag_2y']
bb=bb.reset_index(drop=True)
bb = bb.iloc[::3]
bb.shape
# Out:
# (366,)

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter,AutoMinorLocator
import matplotlib as mpl
plt.style.use('plot_style.txt')
#=========================================================== # Directory and filename; style file open #=========================================================== # Change to the directory which contains the current script 
dirFile = os.path.dirname(os.path.join('YourDirHere',
                          'NicePlotProductivity.py'))
# Load style file plt.style.use(os.path.join(dirFile, 'PaperDoubleFig.mplstyle'))
# Make some style choices for plotting 
colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061']
dashesStyles = [[3,1],
            [1000,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1]]
# Point to the data fileName = 'rftxlicp1017unlinked.xls'
BM_d=YY_test['lag_2y']
BM_d=BM_d.reset_index(drop=True)
BM_d = BM_d.iloc[::3]

# bb=pd.DataFrame(YY_test['EURPrices_Actual'])
# bb=bb.reset_index(drop=True)

figure(figsize = (14, 8), dpi = 90)
plt.plot(DAM_d, color='red', label='DAM prices')
plt.plot(BM_d, color='blue', label='BM prices', alpha=0.2)
plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=18)
plt.ylabel('€/MWh', fontsize=18)
plt.title("SH DNN Forecast of DAM prices", fontsize=18)
# plt.xlim([-20, 380])
plt.ylim([-50,1000])
plt.legend()
# plt.savefig('DAMvsBM.png', transparent=False, format="jpg")

# %%
YY_test
# Out:
#      lag_2y  lag_3y  lag_4y  lag_5y  lag_6y  lag_7y  lag_8y  lag_9y  lag_10y  \
# 0    187.63  140.06  194.62   40.34   30.91  100.34   19.44   46.23    79.54
# 3     64.04   38.06  151.67   52.40   13.84   34.61   45.66   47.94    38.07
# 6     13.46   13.23   14.00    8.05   17.02   15.79   15.64   14.75    11.07
# 9    141.59   76.26   47.00   47.00   41.39   37.47   61.09   59.52    44.62
# 12    15.51    9.70   92.15   38.36   71.71    9.71    8.05   11.08    18.31
# ..      ...     ...     ...     ...     ...     ...     ...     ...      ...
# 813   84.82  106.58   95.53   95.86  117.54  143.99  236.47   88.90   160.65
# 816   85.80   73.81   73.43   61.37   65.72   63.88   65.43   59.98    56.76
# 819   63.91   59.17   57.74   56.14   56.15   60.43   55.64   34.71    38.01
# 822   46.40   54.08   52.97   70.08   62.78   64.43   71.75   63.24    64.45
# 825   42.38   38.58   43.03   36.82   39.54   40.81   53.13   57.62    67.63
#
# ...

# %%
PPreds
# Out:
#      lag_2y_Forecast  lag_3y_Forecast  lag_4y_Forecast  lag_5y_Forecast  \
# 0          38.648170        32.476536        31.193331        29.062019
# 3          42.460312        39.469593        45.802090        47.776623
# 6          35.907719        33.698921        29.112745        25.784027
# 9          33.597740        36.130363        33.225243        32.552563
# 12         31.881565        27.847349        29.424797        24.855537
# ..               ...              ...              ...              ...
# 813        80.128624        76.935829        80.854820        80.591675
# 816        93.047585        98.177467        95.062767        90.233238
# 819        51.207718        51.756912        48.961281        49.481476
# 822        75.351173        76.283287        77.588120        74.127014
# 825        97.250298        90.374641        94.715645        92.585197
#
#      lag_6y_Forecast  lag_7y_Forecast  lag_8y_Forecast  lag_9y_Forecast  \
# ...

# %%
p1=PPreds.iloc[:,:1]
y1=YY_test.iloc[:,:1]
p2=PPreds.iloc[:,1:2]
y2=YY_test.iloc[:,1:2]
p3=PPreds.iloc[:,2:3]
y3=YY_test.iloc[:,2:3]
p4=PPreds.iloc[:,3:4]
y4=YY_test.iloc[:,3:4]
p5=PPreds.iloc[:,4:5]
y5=YY_test.iloc[:,4:5]
p6=PPreds.iloc[:,5:6]
y6=YY_test.iloc[:,5:6]

p7=PPreds.iloc[:,6:7]
y7=YY_test.iloc[:,6:7]
p8=PPreds.iloc[:,7:8]
y8=YY_test.iloc[:,7:8]
p9=PPreds.iloc[:,8:9]
y9=YY_test.iloc[:,8:9]
p10=PPreds.iloc[:,9:10]
y10=YY_test.iloc[:,9:10]
p11=PPreds.iloc[:,10:11]
y11=YY_test.iloc[:,10:11]
p12=PPreds.iloc[:,11:12]
y12=YY_test.iloc[:,11:12]

p13=PPreds.iloc[:,12:13]
y13=YY_test.iloc[:,12:13]
p14=PPreds.iloc[:,13:14]
y14=YY_test.iloc[:,13:14]
p15=PPreds.iloc[:,14:15]
y15=YY_test.iloc[:,14:15]
p16=PPreds.iloc[:,15:16]
y16=YY_test.iloc[:,15:16]
p17=PPreds.iloc[:,16:17]
y17=YY_test.iloc[:,16:17]
p18=PPreds.iloc[:,17:18]
y18=YY_test.iloc[:,17:18]

p19=PPreds.iloc[:,18:19]
y19=YY_test.iloc[:,18:19]
p20=PPreds.iloc[:,19:20]
y20=YY_test.iloc[:,19:20]
p21=PPreds.iloc[:,20:21]
y21=YY_test.iloc[:,20:21]
p22=PPreds.iloc[:,21:22]
y22=YY_test.iloc[:,21:22]
p23=PPreds.iloc[:,22:23]
y23=YY_test.iloc[:,22:23]
p24=PPreds.iloc[:,23:24]
y24=YY_test.iloc[:,23:24]

# %%
p24.shape
# Out:
# (1097, 0)

# %%
p1=PPreds.iloc[::3,:2]
y1=YY_test.iloc[::3,:2]
p2=PPreds.iloc[1::3,:2]
y2=YY_test.iloc[1::3,:2]
p3=PPreds.iloc[2::3,:2]
y3=YY_test.iloc[2::3,:2]
p1=PPreds.iloc[:,:1]
y1=YY_test.iloc[:,:1]
p2=PPreds.iloc[:,1:2]
y2=YY_test.iloc[:,1:2]
p3=PPreds.iloc[:,2:3]
y3=YY_test.iloc[:,2:3]
p4=PPreds.iloc[:,3:4]
y4=YY_test.iloc[:,3:4]
p5=PPreds.iloc[:,4:5]
y5=YY_test.iloc[:,4:5]
p6=PPreds.iloc[:,5:6]
y6=YY_test.iloc[:,5:6]

p7=PPreds.iloc[:,6:7]
y7=YY_test.iloc[:,6:7]
p8=PPreds.iloc[:,7:8]
y8=YY_test.iloc[:,7:8]
p9=PPreds.iloc[:,8:9]
y9=YY_test.iloc[:,8:9]
p10=PPreds.iloc[:,9:10]
y10=YY_test.iloc[:,9:10]
p11=PPreds.iloc[:,10:11]
y11=YY_test.iloc[:,10:11]
p12=PPreds.iloc[:,11:12]
y12=YY_test.iloc[:,11:12]

p13=PPreds.iloc[:,12:13]
y13=YY_test.iloc[:,12:13]
p14=PPreds.iloc[:,13:14]
y14=YY_test.iloc[:,13:14]
p15=PPreds.iloc[:,14:15]
y15=YY_test.iloc[:,14:15]
p16=PPreds.iloc[:,15:16]
y16=YY_test.iloc[:,15:16]
p17=PPreds.iloc[:,16:17]
y17=YY_test.iloc[:,16:17]
p18=PPreds.iloc[:,17:18]
y18=YY_test.iloc[:,17:18]

p19=PPreds.iloc[:,18:19]
y19=YY_test.iloc[:,18:19]
p20=PPreds.iloc[:,19:20]
y20=YY_test.iloc[:,19:20]
p21=PPreds.iloc[:,20:21]
y21=YY_test.iloc[:,20:21]
p22=PPreds.iloc[:,21:22]
y22=YY_test.iloc[:,21:22]
p23=PPreds.iloc[:,22:23]
y23=YY_test.iloc[:,22:23]
p24=PPreds.iloc[:,23:24]
y24=YY_test.iloc[:,23:24]

mse = mean_squared_error(y1, p1)
rmse = sqrt(mse)
mae = mean_absolute_error(y1, p1)
smape = sMAPE(y1, p1)*100
E1 = pd.DataFrame([mae, rmse, smape]).T
print(E1)

mse = mean_squared_error(y2, p2)
rmse = sqrt(mse)
mae = mean_absolute_error(y2, p2)
smape = sMAPE(y2, p2)*100
E2 = pd.DataFrame([mae, rmse, smape]).T
print(E2)

mse = mean_squared_error(y3, p3)
rmse = sqrt(mse)
mae = mean_absolute_error(y3, p3)
smape = sMAPE(y3, p3)*100
E3 = pd.DataFrame([mae, rmse, smape]).T
print(E3)

mse = mean_squared_error(y4, p4)
rmse = sqrt(mse)
mae = mean_absolute_error(y4, p4)
smape = sMAPE(y4, p4)*100
E4 = pd.DataFrame([mae, rmse, smape]).T
print(E4)

mse = mean_squared_error(y5, p5)
rmse = sqrt(mse)
mae = mean_absolute_error(y5, p5)
smape = sMAPE(y5, p5)*100
E5 = pd.DataFrame([mae, rmse, smape]).T
print(E5)

mse = mean_squared_error(y6, p6)
rmse = sqrt(mse)
mae = mean_absolute_error(y6, p6)
smape = sMAPE(y6, p6)*100
E6 = pd.DataFrame([mae, rmse, smape]).T
print(E6)

mse = mean_squared_error(y7, p7)
rmse = sqrt(mse)
mae = mean_absolute_error(y7, p7)
smape = sMAPE(y7, p7)*100
E7 = pd.DataFrame([mae, rmse, smape]).T
print(E7)

mse = mean_squared_error(y8, p8)
rmse = sqrt(mse)
mae = mean_absolute_error(y8, p8)
smape = sMAPE(y8, p8)*100
E8 = pd.DataFrame([mae, rmse, smape]).T
print(E8)

mse = mean_squared_error(y9, p9)
rmse = sqrt(mse)
mae = mean_absolute_error(y9, p9)
smape = sMAPE(y9, p9)*100
E9 = pd.DataFrame([mae, rmse, smape]).T
print(E9)

mse = mean_squared_error(y10, p10)
rmse = sqrt(mse)
mae = mean_absolute_error(y10, p10)
smape = sMAPE(y10, p10)*100
E10 = pd.DataFrame([mae, rmse, smape]).T
print(E10)


mse = mean_squared_error(y11, p11)
rmse = sqrt(mse)
mae = mean_absolute_error(y11, p11)
smape = sMAPE(y11, p11)*100
E11 = pd.DataFrame([mae, rmse, smape]).T
print(E11)

mse = mean_squared_error(y12, p12)
rmse = sqrt(mse)
mae = mean_absolute_error(y12, p12)
smape = sMAPE(y12, p12)*100
E12 = pd.DataFrame([mae, rmse, smape]).T
print(E12)

mse = mean_squared_error(y13, p13)
rmse = sqrt(mse)
mae = mean_absolute_error(y13, p13)
smape = sMAPE(y13, p13)*100
E13 = pd.DataFrame([mae, rmse, smape]).T
print(E13)

mse = mean_squared_error(y14, p14)
rmse = sqrt(mse)
mae = mean_absolute_error(y14, p14)
smape = sMAPE(y14, p14)*100
E14 = pd.DataFrame([mae, rmse, smape]).T
print(E14)

mse = mean_squared_error(y15, p15)
rmse = sqrt(mse)
mae = mean_absolute_error(y15, p15)
smape = sMAPE(y15, p15)*100
E15 = pd.DataFrame([mae, rmse, smape]).T
print(E15)

mse = mean_squared_error(y16, p16)
rmse = sqrt(mse)
mae = mean_absolute_error(y16, p16)
smape = sMAPE(y16, p16)*100
E16 = pd.DataFrame([mae, rmse, smape]).T
print(E16)

mse = mean_squared_error(y17, p17)
rmse = sqrt(mse)
mae = mean_absolute_error(y17, p17)
smape = sMAPE(y17, p17)*100
E17 = pd.DataFrame([mae, rmse, smape]).T
print(E17)

mse = mean_squared_error(y18, p18)
rmse = sqrt(mse)
mae = mean_absolute_error(y18, p18)
smape = sMAPE(y18, p18)*100
E18 = pd.DataFrame([mae, rmse, smape]).T
print(E18)

mse = mean_squared_error(y19, p19)
rmse = sqrt(mse)
mae = mean_absolute_error(y19, p19)
smape = sMAPE(y19, p19)*100
E19 = pd.DataFrame([mae, rmse, smape]).T
print(E19)

mse = mean_squared_error(y20, p20)
rmse = sqrt(mse)
mae = mean_absolute_error(y20, p20)
smape = sMAPE(y20, p20)*100
E20 = pd.DataFrame([mae, rmse, smape]).T
print(E20)

mse = mean_squared_error(y21, p21)
rmse = sqrt(mse)
mae = mean_absolute_error(y21, p21)
smape = sMAPE(y21, p21)*100
E21 = pd.DataFrame([mae, rmse, smape]).T
print(E21)

mse = mean_squared_error(y22, p22)
rmse = sqrt(mse)
mae = mean_absolute_error(y22, p22)
smape = sMAPE(y22, p22)*100
E22 = pd.DataFrame([mae, rmse, smape]).T
print(E22)

mse = mean_squared_error(y23, p23)
rmse = sqrt(mse)
mae = mean_absolute_error(y23, p23)
smape = sMAPE(y23, p23)*100
E23 = pd.DataFrame([mae, rmse, smape]).T
print(E23)

mse = mean_squared_error(y24, p24)
rmse = sqrt(mse)
mae = mean_absolute_error(y24, p24)
smape = sMAPE(y24, p24)*100
E24 = pd.DataFrame([mae, rmse, smape]).T
print(E24)
# Out:
#            0        1          2
# 0  43.352106  85.7278  70.746141
#            0          1          2
# 0  43.450306  84.608219  71.562749
#            0         1         2
# 0  41.784422  81.75583  70.52814
#            0          1          2
# 0  38.443945  61.978007  70.015193
#            0          1          2
# 0  36.756657  55.076567  70.651223
#            0          1          2
# 0  34.404336  51.255284  70.541299
#            0         1          2
# 0  36.138051  56.04354  71.869593
#            0          1          2
# 0  34.396756  54.125299  69.469979
#          0          1          2
# 0  36.2588  55.277985  70.535305
#            0          1          2
# 0  32.816063  47.845932  67.544747
#            0          1          2
# 0  34.325656  50.599007  69.831176
#            0         1          2
# 0  33.462861  49.26107  69.594311
#            0          1          2
# 0  35.299193  51.762546  72.862072
#            0          1          2
# ...

# %%
#            0         1         2          3
# 0  45.845703  6.770945  3.781261  25.157299
#            0         1         2         3
# 0  75.226718  8.673334  5.309169  17.65244
#             0          1         2          3
# 0  344.538654  18.561752  8.477805  16.096059

# %%
figure(figsize = (14, 8), dpi = 90)
plt.plot(pred_nn1['EURPrices_Forecast'], color='green', label='DNN predictions')
plt.plot(Y_test1['EURPrices_Actual'], color='blue', label='DAM prices', alpha=0.2)
# plt.xlabel('Forecast period from 01/06/20-01/09/20',fontsize=18)
plt.ylabel('€/MWh', fontsize=18)
plt.title("Deep Neural Network Forecast of DAM prices", fontsize=18)
# plt.xlim([0, 4400])
plt.ylim([-20,50])
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EURPrices_Forecast'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
YY_test.shape
# Out:
# (1097, 16)

# %%
date_format="%m/%d/%Y %H:%M"
date_parse = lambda date: dt.datetime.strptime(date, date_format)
dat1 = pd.read_csv("/home/ciaran/Documents/experimental_files/fc_nl_datISEMAdj_YT1_CW728.csv")
YY_test=pd.read_csv("/home/ciaran/Documents/ISEMAdj.csv")
dat1=pd.DataFrame(dat1)
YY_test=pd.DataFrame(YY_test)
YY_test=YY_test.iloc[13608:22368,1:2]
YY_test=np.array(YY_test)
YY_test=YY_test.reshape((365,24))
YY_test=pd.DataFrame(YY_test)

# %%
lag_0y1_Forecast=dat1['h0']
lag_0y1_Forecast=lag_0y1_Forecast.dropna()
lag_1y1_Forecast=dat1['h1']
lag_1y1_Forecast=lag_1y1_Forecast.dropna()
lag_2y1_Forecast=dat1['h2']
lag_2y1_Forecast=lag_2y1_Forecast.dropna()
lag_3y1_Forecast=dat1['h3']
lag_3y1_Forecast=lag_3y1_Forecast.dropna()
lag_4y1_Forecast=dat1['h4']
lag_4y1_Forecast=lag_4y1_Forecast.dropna()
lag_5y1_Forecast=dat1['h5']
lag_5y1_Forecast=lag_5y1_Forecast.dropna()
lag_6y1_Forecast=dat1['h6']
lag_6y1_Forecast=lag_6y1_Forecast.dropna()
lag_7y1_Forecast=dat1['h7']
lag_7y1_Forecast=lag_7y1_Forecast.dropna()
lag_8y1_Forecast=dat1['h8']
lag_8y1_Forecast=lag_8y1_Forecast.dropna()
lag_9y1_Forecast=dat1['h9']
lag_9y1_Forecast=lag_9y1_Forecast.dropna()
lag_10y1_Forecast=dat1['h10']
lag_10y1_Forecast=lag_10y1_Forecast.dropna()
lag_11y1_Forecast=dat1['h11']
lag_11y1_Forecast=lag_11y1_Forecast.dropna()
lag_12y1_Forecast=dat1['h12']
lag_12y1_Forecast=lag_12y1_Forecast.dropna()
lag_13y1_Forecast=dat1['h13']
lag_13y1_Forecast=lag_13y1_Forecast.dropna()
lag_14y1_Forecast=dat1['h14']
lag_14y1_Forecast=lag_14y1_Forecast.dropna()
lag_15y1_Forecast=dat1['h15']
lag_15y1_Forecast=lag_15y1_Forecast.dropna()
lag_16y1_Forecast=dat1['h16']
lag_16y1_Forecast=lag_16y1_Forecast.dropna()
lag_17y1_Forecast=dat1['h17']
lag_17y1_Forecast=lag_17y1_Forecast.dropna()
lag_18y1_Forecast=dat1['h18']
lag_18y1_Forecast=lag_18y1_Forecast.dropna()
lag_19y1_Forecast=dat1['h19']
lag_19y1_Forecast=lag_19y1_Forecast.dropna()
lag_20y1_Forecast=dat1['h20']
lag_20y1_Forecast=lag_20y1_Forecast.dropna()
lag_21y1_Forecast=dat1['h21']
lag_21y1_Forecast=lag_21y1_Forecast.dropna()
lag_22y1_Forecast=dat1['h22']
lag_22y1_Forecast=lag_22y1_Forecast.dropna()
lag_23y1_Forecast=dat1['h23']
lag_23y1_Forecast=lag_23y1_Forecast.dropna()
preds=pd.concat([lag_0y1_Forecast, lag_1y1_Forecast, lag_2y1_Forecast, lag_3y1_Forecast, lag_4y1_Forecast, 
                    lag_5y1_Forecast, lag_6y1_Forecast, lag_7y1_Forecast, lag_8y1_Forecast, lag_9y1_Forecast,
                    lag_10y1_Forecast, lag_11y1_Forecast, lag_12y1_Forecast, lag_13y1_Forecast, lag_14y1_Forecast,
                    lag_15y1_Forecast, lag_16y1_Forecast, lag_17y1_Forecast, lag_18y1_Forecast, lag_19y1_Forecast,
                    lag_20y1_Forecast, lag_21y1_Forecast, lag_22y1_Forecast, lag_23y1_Forecast], axis=1)
preds=preds.loc[:364, :]
preds=preds.reset_index(drop=True)
# YY_test=YY_test.reset_index(drop=True)
pred_nn1=preds.iloc[:92,:]
pred_nn2=preds.iloc[92:183,:]
pred_nn3=preds.iloc[183:273,:]
pred_nn4=preds.iloc[273:365,:]
pred_nn1=pred_nn1.reset_index(drop=True)
pred_nn2=pred_nn2.reset_index(drop=True)
pred_nn3=pred_nn3.reset_index(drop=True)
pred_nn4=pred_nn4.reset_index(drop=True)
YY_test=pd.DataFrame(YY_test)
Y_test1=YY_test.iloc[:92,:]
Y_test2=YY_test.iloc[92:183,:]
Y_test3=YY_test.iloc[183:273,:]
Y_test4=YY_test.iloc[273:365,:]
Y_test1=Y_test1.reset_index(drop=True)
Y_test2=Y_test2.reset_index(drop=True)
Y_test3=Y_test3.reset_index(drop=True)
Y_test4=Y_test4.reset_index(drop=True)
print(Y_test1.shape)
print(pred_nn1.shape)
print(Y_test2.shape)
print(pred_nn2.shape)
print(Y_test3.shape)
print(pred_nn3.shape)
print(Y_test4.shape)
print(pred_nn4.shape)
# Out:
# (92, 24)
# (92, 24)
# (91, 24)
# (91, 24)
# (90, 24)
# (90, 24)
# (92, 24)
# (92, 24)

# %%
mse1= mean_squared_error(Y_test1, pred_nn1)
rmse1 = sqrt(mse1)
mae1 = mean_absolute_error(Y_test1, pred_nn1)
smape1 = sMAPE(Y_test1, pred_nn1)*100
Error_1 = pd.DataFrame([mse1, rmse1, mae1, smape1]).T

mse2 = mean_squared_error(Y_test2, pred_nn2)
rmse2 = sqrt(mse2)
mae2 = mean_absolute_error(Y_test2, pred_nn2)
smape2 = sMAPE(Y_test2, pred_nn2)*100
Error_2 = pd.DataFrame([mse2, rmse2, mae2, smape2]).T

mse3 = mean_squared_error(Y_test3, pred_nn3)
rmse3 = sqrt(mse3)
mae3 = mean_absolute_error(Y_test3, pred_nn3)
smape3 = sMAPE(Y_test3, pred_nn3)*100
Error_3 = pd.DataFrame([mse3, rmse3, mae3, smape3]).T

mse4 = mean_squared_error(Y_test4, pred_nn4)
rmse4 = sqrt(mse4)
mae4 = mean_absolute_error(Y_test4, pred_nn4)
smape4 = sMAPE(Y_test4, pred_nn4)*100
Error_4 = pd.DataFrame([mse4, rmse4, mae4, smape4]).T

YY_test=pd.concat([Y_test1, Y_test2, Y_test3, Y_test4], axis=0)
PPreds=pd.concat([pred_nn1,pred_nn2, pred_nn3, pred_nn4], axis=0)
mse = mean_squared_error(YY_test, PPreds)
rmse = sqrt(mse)
mae = mean_absolute_error(YY_test, PPreds)
smape = sMAPE(YY_test, PPreds)*100
Erroru = pd.DataFrame([mse, rmse, mae, smape]).T
print(Y_test1.shape)
print(pred_nn1.shape)
print(Y_test2.shape)
print(pred_nn2.shape)
print(Y_test3.shape)
print(pred_nn3.shape)
print(Y_test4.shape)
print(pred_nn4.shape)
print(Error_1)
print(Error_2)
print(Error_3)
print(Error_4)
print(Erroru)
# Out:
# (92, 24)
# (92, 24)
# (91, 24)
# (91, 24)
# (90, 24)
# (90, 24)
# (92, 24)
# (92, 24)
#           0         1        2          3
# 0  60.99421  7.809879  5.44085  23.137561
#             0          1         2         3
# 0  261.400049  16.167871  8.940044  24.84671
#             0          1          2          3
# 0  486.233128  22.050695  11.624361  23.130288
#             0          1          2          3
# 0  613.521472  24.769366  14.598427  19.635694
#             0         1          2          3
# 0  355.078983  18.84354  10.146164  22.679222

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter,AutoMinorLocator
import matplotlib as mpl
plt.style.use('plot_style.txt')
#=========================================================== # Directory and filename; style file open #=========================================================== # Change to the directory which contains the current script 
dirFile = os.path.dirname(os.path.join('YourDirHere',
                          'NicePlotProductivity.py'))
# Load style file plt.style.use(os.path.join(dirFile, 'PaperDoubleFig.mplstyle'))
# Make some style choices for plotting 
colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061']
dashesStyles = [[3,1],
            [1000,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1]]
# Point to the data fileName = 'rftxlicp1017unlinked.xls'
aa=pd.DataFrame(PPreds['h0'])
aa=aa.reset_index(drop=True)
bb=pd.DataFrame(YY_test.loc[:, :0])
bb=bb.reset_index(drop=True)

figure(figsize = (14, 8), dpi = 90)
plt.plot(aa, color='red', label='LEAR DAM predictions')
plt.plot(bb, color='blue', label='DAM prices', alpha=0.2)
plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=22)
plt.ylabel('€/MWh', fontsize=18)
plt.xlim([-20, 380])
# plt.ylim([-200,600])
plt.legend(fontsize=20)
plt.savefig('DAM_LEAR.png', transparent=False, format="jpg")

# %%
p1=PPreds.iloc[::3,:2]
y1=YY_test.iloc[::3,:2]
p2=PPreds.iloc[1::3,:2]
y2=YY_test.iloc[1::3,:2]
p3=PPreds.iloc[2::3,:2]
y3=YY_test.iloc[2::3,:2]
p1=PPreds.iloc[:,:1]
y1=YY_test.iloc[:,:1]
p2=PPreds.iloc[:,1:2]
y2=YY_test.iloc[:,1:2]
p3=PPreds.iloc[:,2:3]
y3=YY_test.iloc[:,2:3]
p4=PPreds.iloc[:,3:4]
y4=YY_test.iloc[:,3:4]
p5=PPreds.iloc[:,4:5]
y5=YY_test.iloc[:,4:5]
p6=PPreds.iloc[:,5:6]
y6=YY_test.iloc[:,5:6]

p7=PPreds.iloc[:,6:7]
y7=YY_test.iloc[:,6:7]
p8=PPreds.iloc[:,7:8]
y8=YY_test.iloc[:,7:8]
p9=PPreds.iloc[:,8:9]
y9=YY_test.iloc[:,8:9]
p10=PPreds.iloc[:,9:10]
y10=YY_test.iloc[:,9:10]
p11=PPreds.iloc[:,10:11]
y11=YY_test.iloc[:,10:11]
p12=PPreds.iloc[:,11:12]
y12=YY_test.iloc[:,11:12]

p13=PPreds.iloc[:,12:13]
y13=YY_test.iloc[:,12:13]
p14=PPreds.iloc[:,13:14]
y14=YY_test.iloc[:,13:14]
p15=PPreds.iloc[:,14:15]
y15=YY_test.iloc[:,14:15]
p16=PPreds.iloc[:,15:16]
y16=YY_test.iloc[:,15:16]
p17=PPreds.iloc[:,16:17]
y17=YY_test.iloc[:,16:17]
p18=PPreds.iloc[:,17:18]
y18=YY_test.iloc[:,17:18]

p19=PPreds.iloc[:,18:19]
y19=YY_test.iloc[:,18:19]
p20=PPreds.iloc[:,19:20]
y20=YY_test.iloc[:,19:20]
p21=PPreds.iloc[:,20:21]
y21=YY_test.iloc[:,20:21]
p22=PPreds.iloc[:,21:22]
y22=YY_test.iloc[:,21:22]
p23=PPreds.iloc[:,22:23]
y23=YY_test.iloc[:,22:23]
p24=PPreds.iloc[:,23:24]
y24=YY_test.iloc[:,23:24]

mse = mean_squared_error(y1, p1)
rmse = sqrt(mse)
mae = mean_absolute_error(y1, p1)
smape = sMAPE(y1, p1)*100
E1 = pd.DataFrame([mae, rmse, smape]).T
print(E1)

mse = mean_squared_error(y2, p2)
rmse = sqrt(mse)
mae = mean_absolute_error(y2, p2)
smape = sMAPE(y2, p2)*100
E2 = pd.DataFrame([mae, rmse, smape]).T
print(E2)

mse = mean_squared_error(y3, p3)
rmse = sqrt(mse)
mae = mean_absolute_error(y3, p3)
smape = sMAPE(y3, p3)*100
E3 = pd.DataFrame([mae, rmse, smape]).T
print(E3)

mse = mean_squared_error(y4, p4)
rmse = sqrt(mse)
mae = mean_absolute_error(y4, p4)
smape = sMAPE(y4, p4)*100
E4 = pd.DataFrame([mae, rmse, smape]).T
print(E4)

mse = mean_squared_error(y5, p5)
rmse = sqrt(mse)
mae = mean_absolute_error(y5, p5)
smape = sMAPE(y5, p5)*100
E5 = pd.DataFrame([mae, rmse, smape]).T
print(E5)

mse = mean_squared_error(y6, p6)
rmse = sqrt(mse)
mae = mean_absolute_error(y6, p6)
smape = sMAPE(y6, p6)*100
E6 = pd.DataFrame([mae, rmse, smape]).T
print(E6)

mse = mean_squared_error(y7, p7)
rmse = sqrt(mse)
mae = mean_absolute_error(y7, p7)
smape = sMAPE(y7, p7)*100
E7 = pd.DataFrame([mae, rmse, smape]).T
print(E7)

mse = mean_squared_error(y8, p8)
rmse = sqrt(mse)
mae = mean_absolute_error(y8, p8)
smape = sMAPE(y8, p8)*100
E8 = pd.DataFrame([mae, rmse, smape]).T
print(E8)

mse = mean_squared_error(y9, p9)
rmse = sqrt(mse)
mae = mean_absolute_error(y9, p9)
smape = sMAPE(y9, p9)*100
E9 = pd.DataFrame([mae, rmse, smape]).T
print(E9)

mse = mean_squared_error(y10, p10)
rmse = sqrt(mse)
mae = mean_absolute_error(y10, p10)
smape = sMAPE(y10, p10)*100
E10 = pd.DataFrame([mae, rmse, smape]).T
print(E10)


mse = mean_squared_error(y11, p11)
rmse = sqrt(mse)
mae = mean_absolute_error(y11, p11)
smape = sMAPE(y11, p11)*100
E11 = pd.DataFrame([mae, rmse, smape]).T
print(E11)

mse = mean_squared_error(y12, p12)
rmse = sqrt(mse)
mae = mean_absolute_error(y12, p12)
smape = sMAPE(y12, p12)*100
E12 = pd.DataFrame([mae, rmse, smape]).T
print(E12)

mse = mean_squared_error(y13, p13)
rmse = sqrt(mse)
mae = mean_absolute_error(y13, p13)
smape = sMAPE(y13, p13)*100
E13 = pd.DataFrame([mae, rmse, smape]).T
print(E13)

mse = mean_squared_error(y14, p14)
rmse = sqrt(mse)
mae = mean_absolute_error(y14, p14)
smape = sMAPE(y14, p14)*100
E14 = pd.DataFrame([mae, rmse, smape]).T
print(E14)

mse = mean_squared_error(y15, p15)
rmse = sqrt(mse)
mae = mean_absolute_error(y15, p15)
smape = sMAPE(y15, p15)*100
E15 = pd.DataFrame([mae, rmse, smape]).T
print(E15)

mse = mean_squared_error(y16, p16)
rmse = sqrt(mse)
mae = mean_absolute_error(y16, p16)
smape = sMAPE(y16, p16)*100
E16 = pd.DataFrame([mae, rmse, smape]).T
print(E16)

mse = mean_squared_error(y17, p17)
rmse = sqrt(mse)
mae = mean_absolute_error(y17, p17)
smape = sMAPE(y17, p17)*100
E17 = pd.DataFrame([mae, rmse, smape]).T
print(E17)

mse = mean_squared_error(y18, p18)
rmse = sqrt(mse)
mae = mean_absolute_error(y18, p18)
smape = sMAPE(y18, p18)*100
E18 = pd.DataFrame([mae, rmse, smape]).T
print(E18)

mse = mean_squared_error(y19, p19)
rmse = sqrt(mse)
mae = mean_absolute_error(y19, p19)
smape = sMAPE(y19, p19)*100
E19 = pd.DataFrame([mae, rmse, smape]).T
print(E19)

mse = mean_squared_error(y20, p20)
rmse = sqrt(mse)
mae = mean_absolute_error(y20, p20)
smape = sMAPE(y20, p20)*100
E20 = pd.DataFrame([mae, rmse, smape]).T
print(E20)

mse = mean_squared_error(y21, p21)
rmse = sqrt(mse)
mae = mean_absolute_error(y21, p21)
smape = sMAPE(y21, p21)*100
E21 = pd.DataFrame([mae, rmse, smape]).T
print(E21)

mse = mean_squared_error(y22, p22)
rmse = sqrt(mse)
mae = mean_absolute_error(y22, p22)
smape = sMAPE(y22, p22)*100
E22 = pd.DataFrame([mae, rmse, smape]).T
print(E22)

mse = mean_squared_error(y23, p23)
rmse = sqrt(mse)
mae = mean_absolute_error(y23, p23)
smape = sMAPE(y23, p23)*100
E23 = pd.DataFrame([mae, rmse, smape]).T
print(E23)

mse = mean_squared_error(y24, p24)
rmse = sqrt(mse)
mae = mean_absolute_error(y24, p24)
smape = sMAPE(y24, p24)*100
E24 = pd.DataFrame([mae, rmse, smape]).T
print(E24)
# Out:
#           0         1          2
# 0  4.909763  7.351822  22.456013
#           0         1          2
# 0  6.909866  9.825745  30.643328
#           0          1          2
# 0  7.784149  11.094143  35.558681
#           0          1          2
# 0  7.894246  11.348208  37.149569
#          0          1          2
# 0  7.74999  11.285856  35.818167
#           0          1          2
# 0  8.626932  12.178902  36.391805
#           0          1         2
# 0  8.990945  12.894204  31.26073
#           0          1          2
# 0  8.865988  14.051206  20.393208
#            0          1          2
# 0  10.322631  17.256577  20.001072
#          0          1          2
# 0  9.92849  15.202739  17.985688
#           0          1          2
# 0  9.434815  15.227153  15.087025
#           0          1          2
# 0  9.554953  15.996436  14.984404
#            0          1          2
# 0  10.719859  17.479435  16.767922
#           0          1          2
# ...

# %%
aa=pd.DataFrame(PPreds['h0'])
aa=aa.reset_index(drop=True)
bb=pd.DataFrame(YY_test.loc[:, :0])
bb=bb.reset_index(drop=True)

# %%
figure(figsize = (14, 8), dpi = 90)
plt.plot(aa, color='red', label='LEAR DAM predictions')
plt.plot(bb, color='blue', label='DAM prices', alpha=0.2)
plt.xlabel('Forecast period from 01/06/20-01/06/21',fontsize=18)
plt.ylabel('€/MWh', fontsize=18)
plt.title("Deep Neural Network Forecast of DAM prices", fontsize=18)
# plt.xlim([0, 4400])
# plt.ylim([-20,50])
plt.legend()
plt.savefig('DAM_LEAR.png', transparent=False, format="jpg")

# %%
YY_test.loc[:, :0]

# %%
YY_test.loc[:, :1]

# %%
YY_test
